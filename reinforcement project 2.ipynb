# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A41447/ADM-2303A51447/blob/main/reinforcement%20project%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np

# -----------------------------------------
# SMART TRAFFIC LIGHT RL – NO SUMO VERSION
# -----------------------------------------

class SmartTrafficEnv:
    """
    Simple simulated environment for a traffic light with 2 directions:
    - North-South (NS)
    - East-West (EW)

    Each direction has queue increasing randomly.
    The RL agent selects which direction gets GREEN.
    """

    def __init__(self):
        self.state = [0, 0]   # [NS_queue, EW_queue]
        self.max_cars = 20
        self.done = False

    def reset(self):
        self.state = [random.randint(0, 5), random.randint(0, 5)]
        self.done = False
        return self.state

    def step(self, action):
        """
        action = 0 → NS green
        action = 1 → EW green
        """

        # Cars arrive randomly (0–3 cars)
        arrivals_NS = random.randint(0, 3)
        arrivals_EW = random.randint(0, 3)

        self.state[0] += arrivals_NS
        self.state[1] += arrivals_EW

        # Cars pass on the green light
        if action == 0:   # NS green
            self.state[0] = max(0, self.state[0] - random.randint(2, 5))
        else:             # EW green
            self.state[1] = max(0, self.state[1] - random.randint(2, 5))

        # Reward = negative total queue length
        reward = -(self.state[0] + self.state[1])

        # Episode ends if queues get too large
        if self.state[0] > self.max_cars or self.state[1] > self.max_cars:
            self.done = True

        return self.state, reward, self.done


# -----------------------------------------
# Q-LEARNING AGENT
# -----------------------------------------

class QLearningAgent:
    def __init__(self, alpha=0.1, gamma=0.9, epsilon=0.2):
        self.q_table = {}      # key: state, value: [Q_NS, Q_EW]
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def get_q(self, state):
        state_key = tuple(state)
        if state_key not in self.q_table:
            self.q_table[state_key] = [0, 0]
        return self.q_table[state_key]

    def choose_action(self, state):
        if random.random() < self.epsilon:
            return random.choice([0, 1])  # explore
        return np.argmax(self.get_q(state))  # exploit

    def update(self, state, action, reward, next_state):
        q_values = self.get_q(state)
        max_future = max(self.get_q(next_state))
        q_values[action] += self.alpha * (reward + self.gamma * max_future - q_values[action])


# -----------------------------------------
# TRAINING LOOP
# -----------------------------------------

env = SmartTrafficEnv()
agent = QLearningAgent()

EPISODES = 300

for ep in range(EPISODES):
    state = env.reset()
    total_reward = 0

    while True:
        action = agent.choose_action(state)
        next_state, reward, done = env.step(action)
        agent.update(state, action, reward, next_state)

        state = next_state
        total_reward += reward

        if done:
            break

    print(f"Episode {ep+1}: total reward = {total_reward}")

print("\nTraining complete!")
print("Q-Table size:", len(agent.q_table))
# Out:
# Episode 1: total reward = -235
# Episode 2: total reward = -1011
# Episode 3: total reward = -67376
# Episode 4: total reward = -64860
# Episode 5: total reward = -31750
# Episode 6: total reward = -9649
# Episode 7: total reward = -34982
# Episode 8: total reward = -55608
# Episode 9: total reward = -30163
# Episode 10: total reward = -28185
# Episode 11: total reward = -30146
# Episode 12: total reward = -149577
# Episode 13: total reward = -55644
# Episode 14: total reward = -8090
# Episode 15: total reward = -35533
# Episode 16: total reward = -138406
# Episode 17: total reward = -13743
# Episode 18: total reward = -59225
# Episode 19: total reward = -167155
# Episode 20: total reward = -44477
# Episode 21: total reward = -221151
# Episode 22: total reward = -12198
# Episode 23: total reward = -30895
# Episode 24: total reward = -14208
# Episode 25: total reward = -54226
# Episode 26: total reward = -193332
# Episode 27: total reward = -18640
# Episode 28: total reward = -66123
# Episode 29: total reward = -29304
# Episode 30: total reward = -54213
# Episode 31: total reward = -87505
# Episode 32: total reward = -35282
# Episode 33: total reward = -3607
# Episode 34: total reward = -294095
# Episode 35: total reward = -20837
# Episode 36: total reward = -132743
# Episode 37: total reward = -179636
# Episode 38: total reward = -36038
# Episode 39: total reward = -279346
# Episode 40: total reward = -107632
# Episode 41: total reward = -128102
# Episode 42: total reward = -137423
# Episode 43: total reward = -5050
# Episode 44: total reward = -15292
# Episode 45: total reward = -16193
# Episode 46: total reward = -89624
# Episode 47: total reward = -369061
# Episode 48: total reward = -134309
# Episode 49: total reward = -409727
# Episode 50: total reward = -39833
# Episode 51: total reward = -17003
# Episode 52: total reward = -62518
# Episode 53: total reward = -17902
# Episode 54: total reward = -97216
# Episode 55: total reward = -25541
# Episode 56: total reward = -81098
# Episode 57: total reward = -67960
# Episode 58: total reward = -72524
# Episode 59: total reward = -130607
# Episode 60: total reward = -19706
# Episode 61: total reward = -181681
# Episode 62: total reward = -96603
# Episode 63: total reward = -16556
# Episode 64: total reward = -67332
# Episode 65: total reward = -16864
# Episode 66: total reward = -21610
# Episode 67: total reward = -35262
# Episode 68: total reward = -20136
# Episode 69: total reward = -87009
# Episode 70: total reward = -123105
# Episode 71: total reward = -34398
# Episode 72: total reward = -40135
# Episode 73: total reward = -106030
# Episode 74: total reward = -28977
# Episode 75: total reward = -163463
# Episode 76: total reward = -40323
# Episode 77: total reward = -105514
# Episode 78: total reward = -59737
# Episode 79: total reward = -19902
# Episode 80: total reward = -42475
# Episode 81: total reward = -93634
# Episode 82: total reward = -25904
# Episode 83: total reward = -132682
# Episode 84: total reward = -11769
# Episode 85: total reward = -31229
# Episode 86: total reward = -38652
# Episode 87: total reward = -19294
# Episode 88: total reward = -21169
# Episode 89: total reward = -7769
# Episode 90: total reward = -9748
# Episode 91: total reward = -24686
# Episode 92: total reward = -6172
# Episode 93: total reward = -65943
# Episode 94: total reward = -16362
# Episode 95: total reward = -19414
# Episode 96: total reward = -8494
# Episode 97: total reward = -11707
# Episode 98: total reward = -17696
# Episode 99: total reward = -13903
# Episode 100: total reward = -14148
# Episode 101: total reward = -8603
# Episode 102: total reward = -9451
# Episode 103: total reward = -10238
# Episode 104: total reward = -626
# Episode 105: total reward = -47251
# Episode 106: total reward = -18777
# Episode 107: total reward = -2460
# Episode 108: total reward = -1218
# Episode 109: total reward = -10998
# Episode 110: total reward = -8317
# Episode 111: total reward = -1309
# Episode 112: total reward = -8896
# Episode 113: total reward = -13550
# Episode 114: total reward = -12160
# Episode 115: total reward = -1456
# Episode 116: total reward = -26705
# Episode 117: total reward = -228293
# Episode 118: total reward = -95686
# Episode 119: total reward = -29401
# Episode 120: total reward = -7319
# Episode 121: total reward = -2978
# Episode 122: total reward = -18756
# Episode 123: total reward = -20509
# Episode 124: total reward = -53080
# Episode 125: total reward = -25482
# Episode 126: total reward = -75523
# Episode 127: total reward = -32143
# Episode 128: total reward = -7517
# Episode 129: total reward = -26431
# Episode 130: total reward = -10495
# Episode 131: total reward = -13242
# Episode 132: total reward = -30304
# Episode 133: total reward = -31073
# Episode 134: total reward = -10462
# Episode 135: total reward = -16768
# Episode 136: total reward = -13781
# Episode 137: total reward = -14460
# Episode 138: total reward = -1253
# Episode 139: total reward = -7709
# Episode 140: total reward = -4399
# Episode 141: total reward = -9139
# Episode 142: total reward = -17145
# Episode 143: total reward = -15977
# Episode 144: total reward = -11622
# Episode 145: total reward = -38525
# Episode 146: total reward = -2361
# Episode 147: total reward = -9799
# Episode 148: total reward = -17251
# Episode 149: total reward = -36735
# Episode 150: total reward = -50677
# Episode 151: total reward = -4295
# Episode 152: total reward = -5200
# Episode 153: total reward = -24697
# Episode 154: total reward = -7083
# Episode 155: total reward = -12176
# Episode 156: total reward = -10497
# Episode 157: total reward = -2667
# Episode 158: total reward = -5054
# Episode 159: total reward = -1425
# Episode 160: total reward = -6162
# Episode 161: total reward = -3679
# Episode 162: total reward = -4804
# Episode 163: total reward = -2361
# Episode 164: total reward = -5403
# Episode 165: total reward = -11802
# Episode 166: total reward = -3257
# Episode 167: total reward = -18056
# Episode 168: total reward = -1371
# Episode 169: total reward = -201
# Episode 170: total reward = -17545
# Episode 171: total reward = -17891
# Episode 172: total reward = -9493
# Episode 173: total reward = -10412
# Episode 174: total reward = -8625
# Episode 175: total reward = -1399
# Episode 176: total reward = -48213
# Episode 177: total reward = -15913
# Episode 178: total reward = -26175
# Episode 179: total reward = -12359
# Episode 180: total reward = -2152
# Episode 181: total reward = -7399
# Episode 182: total reward = -34707
# Episode 183: total reward = -873
# Episode 184: total reward = -4672
# Episode 185: total reward = -8916
# Episode 186: total reward = -56957
# Episode 187: total reward = -9616
# Episode 188: total reward = -10448
# Episode 189: total reward = -133982
# Episode 190: total reward = -9185
# Episode 191: total reward = -8837
# Episode 192: total reward = -5391
# Episode 193: total reward = -23209
# Episode 194: total reward = -6076
# Episode 195: total reward = -4068
# Episode 196: total reward = -7148
# Episode 197: total reward = -23216
# Episode 198: total reward = -17943
# Episode 199: total reward = -19765
# Episode 200: total reward = -4221
# Episode 201: total reward = -13082
# Episode 202: total reward = -16547
# Episode 203: total reward = -9939
# Episode 204: total reward = -47606
# Episode 205: total reward = -10448
# Episode 206: total reward = -11657
# Episode 207: total reward = -21302
# Episode 208: total reward = -15279
# Episode 209: total reward = -8554
# Episode 210: total reward = -14359
# Episode 211: total reward = -23629
# Episode 212: total reward = -2599
# Episode 213: total reward = -7036
# Episode 214: total reward = -4399
# Episode 215: total reward = -27936
# Episode 216: total reward = -25112
# Episode 217: total reward = -7769
# Episode 218: total reward = -4357
# Episode 219: total reward = -26457
# Episode 220: total reward = -5867
# Episode 221: total reward = -1721
# Episode 222: total reward = -20704
# Episode 223: total reward = -23105
# Episode 224: total reward = -3258
# Episode 225: total reward = -20009
# Episode 226: total reward = -17906
# Episode 227: total reward = -4992
# Episode 228: total reward = -9307
# Episode 229: total reward = -4105
# Episode 230: total reward = -10589
# Episode 231: total reward = -6736
# Episode 232: total reward = -7355
# Episode 233: total reward = -94289
# Episode 234: total reward = -16798
# Episode 235: total reward = -15347
# Episode 236: total reward = -20752
# Episode 237: total reward = -5331
# Episode 238: total reward = -55057
# Episode 239: total reward = -20964
# Episode 240: total reward = -23273
# Episode 241: total reward = -2635
# Episode 242: total reward = -24692
# Episode 243: total reward = -3788
# Episode 244: total reward = -7909
# Episode 245: total reward = -18698
# Episode 246: total reward = -19170
# Episode 247: total reward = -10124
# Episode 248: total reward = -15451
# Episode 249: total reward = -9197
# Episode 250: total reward = -5800
# Episode 251: total reward = -6611
# Episode 252: total reward = -46349
# Episode 253: total reward = -3014
# Episode 254: total reward = -8936
# Episode 255: total reward = -20161
# Episode 256: total reward = -3956
# Episode 257: total reward = -8788
# Episode 258: total reward = -3278
# Episode 259: total reward = -7167
# Episode 260: total reward = -1011
# Episode 261: total reward = -7467
# Episode 262: total reward = -22929
# Episode 263: total reward = -27021
# Episode 264: total reward = -5610
# Episode 265: total reward = -1613
# Episode 266: total reward = -4205
# Episode 267: total reward = -1491
# Episode 268: total reward = -7261
# Episode 269: total reward = -12466
# Episode 270: total reward = -458
# Episode 271: total reward = -4077
# Episode 272: total reward = -416
# Episode 273: total reward = -15849
# Episode 274: total reward = -3088
# Episode 275: total reward = -2304
# Episode 276: total reward = -9339
# Episode 277: total reward = -24849
# Episode 278: total reward = -5540
# Episode 279: total reward = -16138
# Episode 280: total reward = -6484
# Episode 281: total reward = -4108
# Episode 282: total reward = -9066
# Episode 283: total reward = -26146
# Episode 284: total reward = -2117
# Episode 285: total reward = -20840
# Episode 286: total reward = -21280
# Episode 287: total reward = -6102
# Episode 288: total reward = -34080
# Episode 289: total reward = -12423
# Episode 290: total reward = -1929
# Episode 291: total reward = -1402
# Episode 292: total reward = -19116
# Episode 293: total reward = -12611
# Episode 294: total reward = -4087
# Episode 295: total reward = -7285
# Episode 296: total reward = -16962
# Episode 297: total reward = -5863
# Episode 298: total reward = -1220
# Episode 299: total reward = -16824
# Episode 300: total reward = -12880
#
# Training complete!
# Q-Table size: 480

# %%
import random
import numpy as np

# -------------------------------------------------------
# SMART TRAFFIC LIGHT ENVIRONMENT (NO SUMO)
# -------------------------------------------------------
class SmartTrafficEnv:
    """
    Simulated traffic light with:
    - 2 directions: North-South (NS) and East-West (EW)
    - Cars arrive randomly
    - RL agent chooses which direction gets GREEN
    """

    def __init__(self):
        self.max_queue = 30
        self.reset()

    def reset(self):
        # Initial queues of cars
        self.state = [random.randint(0, 5), random.randint(0, 5)]  # [NS_queue, EW_queue]
        self.done = False
        return self.state

    def step(self, action):
        """
        action = 0 → NS green
        action = 1 → EW green
        """

        # Random car arrivals (0–3 cars per direction)
        self.state[0] += random.randint(0, 3)
        self.state[1] += random.randint(0, 3)

        # Green light reduces queue
        if action == 0:  # NS
            self.state[0] = max(0, self.state[0] - random.randint(2, 6))
        else:            # EW
            self.state[1] = max(0, self.state[1] - random.randint(2, 6))

        # Reward = negative total queue -> minimize traffic
        reward = -(self.state[0] + self.state[1])

        # Episode ends if queue grows too large
        if self.state[0] > self.max_queue or self.state[1] > self.max_queue:
            self.done = True

        return self.state, reward, self.done


# -------------------------------------------------------
# Q-LEARNING AGENT
# -------------------------------------------------------
class QLearningAgent:
    def __init__(self, alpha=0.2, gamma=0.9, epsilon=0.1):
        self.q_table = {}  # state → [q_NS, q_EW]
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def get_qs(self, state):
        key = tuple(state)
        if key not in self.q_table:
            self.q_table[key] = [0, 0]  # [Q for NS, Q for EW]
        return self.q_table[key]

    def choose_action(self, state):
        # Exploration
        if random.random() < self.epsilon:
            return random.randint(0, 1)

        # Exploitation (choose best action)
        qs = self.get_qs(state)
        return np.argmax(qs)

    def update(self, state, action, reward, next_state):
        qs = self.get_qs(state)
        max_future_q = max(self.get_qs(next_state))
        qs[action] += self.alpha * (reward + self.gamma * max_future_q - qs[action])


# -------------------------------------------------------
# TRAINING LOOP
# -------------------------------------------------------
env = SmartTrafficEnv()
agent = QLearningAgent()

EPISODES = 300

for episode in range(EPISODES):
    state = env.reset()
    total_reward = 0

    while True:
        action = agent.choose_action(state)
        next_state, reward, done = env.step(action)
        agent.update(state, action, reward, next_state)

        state = next_state
        total_reward += reward

        if done:
            break

    print(f"Episode {episode+1}: Total Reward = {total_reward}")

print("\nTraining Completed!")
print("Q-table entries:", len(agent.q_table))
# Out:
# Episode 1: Total Reward = -6447239
# Episode 2: Total Reward = -622922
# Episode 3: Total Reward = -1456251
# Episode 4: Total Reward = -1024462
# Episode 5: Total Reward = -68705
# Episode 6: Total Reward = -22485
# Episode 7: Total Reward = -133813
# Episode 8: Total Reward = -17684
# Episode 9: Total Reward = -30506
# Episode 10: Total Reward = -163314
# Episode 11: Total Reward = -99481
# Episode 12: Total Reward = -306291
# Episode 13: Total Reward = -345255
# Episode 14: Total Reward = -21973
# Episode 15: Total Reward = -115143
# Episode 16: Total Reward = -243560
# Episode 17: Total Reward = -154798
# Episode 18: Total Reward = -62809
# Episode 19: Total Reward = -83405
# Episode 20: Total Reward = -28835
# Episode 21: Total Reward = -62426
# Episode 22: Total Reward = -125732
# Episode 23: Total Reward = -53124
# Episode 24: Total Reward = -45882
# Episode 25: Total Reward = -252953
# Episode 26: Total Reward = -40566
# Episode 27: Total Reward = -212741
# Episode 28: Total Reward = -98975
# Episode 29: Total Reward = -107022
# Episode 30: Total Reward = -27793
# Episode 31: Total Reward = -153141
# Episode 32: Total Reward = -43142
# Episode 33: Total Reward = -12419
# Episode 34: Total Reward = -489727
# Episode 35: Total Reward = -16098
# Episode 36: Total Reward = -52700
# Episode 37: Total Reward = -13882
# Episode 38: Total Reward = -155858
# Episode 39: Total Reward = -1600
# Episode 40: Total Reward = -25736
# Episode 41: Total Reward = -18050
# Episode 42: Total Reward = -12919
# Episode 43: Total Reward = -36502
# Episode 44: Total Reward = -56373
# Episode 45: Total Reward = -144196
# Episode 46: Total Reward = -100627
# Episode 47: Total Reward = -59997
# Episode 48: Total Reward = -88864
# Episode 49: Total Reward = -59451
# Episode 50: Total Reward = -40822
# Episode 51: Total Reward = -32523
# Episode 52: Total Reward = -39873
# Episode 53: Total Reward = -8912
# Episode 54: Total Reward = -35946
# Episode 55: Total Reward = -46747
# Episode 56: Total Reward = -4094
# Episode 57: Total Reward = -17364
# Episode 58: Total Reward = -85497
# Episode 59: Total Reward = -28788
# Episode 60: Total Reward = -28168
# Episode 61: Total Reward = -25346
# Episode 62: Total Reward = -9097
# Episode 63: Total Reward = -52639
# Episode 64: Total Reward = -39879
# Episode 65: Total Reward = -8545
# Episode 66: Total Reward = -135677
# Episode 67: Total Reward = -69086
# Episode 68: Total Reward = -60823
# Episode 69: Total Reward = -76677
# Episode 70: Total Reward = -2290
# Episode 71: Total Reward = -17178
# Episode 72: Total Reward = -28077
# Episode 73: Total Reward = -7413
# Episode 74: Total Reward = -41270
# Episode 75: Total Reward = -68739
# Episode 76: Total Reward = -10158
# Episode 77: Total Reward = -10755
# Episode 78: Total Reward = -22555
# Episode 79: Total Reward = -102705
# Episode 80: Total Reward = -1723
# Episode 81: Total Reward = -67920
# Episode 82: Total Reward = -19531
# Episode 83: Total Reward = -14967
# Episode 84: Total Reward = -58948
# Episode 85: Total Reward = -91271
# Episode 86: Total Reward = -5845
# Episode 87: Total Reward = -5444
# Episode 88: Total Reward = -98049
# Episode 89: Total Reward = -4083
# Episode 90: Total Reward = -67875
# Episode 91: Total Reward = -6245
# Episode 92: Total Reward = -4839
# Episode 93: Total Reward = -35915
# Episode 94: Total Reward = -55437
# Episode 95: Total Reward = -15260
# Episode 96: Total Reward = -33091
# Episode 97: Total Reward = -40961
# Episode 98: Total Reward = -12549
# Episode 99: Total Reward = -18737
# Episode 100: Total Reward = -10701
# Episode 101: Total Reward = -7503
# Episode 102: Total Reward = -38576
# Episode 103: Total Reward = -7923
# Episode 104: Total Reward = -32432
# Episode 105: Total Reward = -33758
# Episode 106: Total Reward = -17305
# Episode 107: Total Reward = -10813
# Episode 108: Total Reward = -32844
# Episode 109: Total Reward = -82319
# Episode 110: Total Reward = -35644
# Episode 111: Total Reward = -20628
# Episode 112: Total Reward = -46311
# Episode 113: Total Reward = -14591
# Episode 114: Total Reward = -62729
# Episode 115: Total Reward = -14564
# Episode 116: Total Reward = -63927
# Episode 117: Total Reward = -64087
# Episode 118: Total Reward = -5668
# Episode 119: Total Reward = -1789
# Episode 120: Total Reward = -12288
# Episode 121: Total Reward = -31718
# Episode 122: Total Reward = -12456
# Episode 123: Total Reward = -2744
# Episode 124: Total Reward = -22736
# Episode 125: Total Reward = -16372
# Episode 126: Total Reward = -6715
# Episode 127: Total Reward = -4085
# Episode 128: Total Reward = -6575
# Episode 129: Total Reward = -44163
# Episode 130: Total Reward = -29527
# Episode 131: Total Reward = -3130
# Episode 132: Total Reward = -4899
# Episode 133: Total Reward = -54432
# Episode 134: Total Reward = -3702
# Episode 135: Total Reward = -21648
# Episode 136: Total Reward = -23693
# Episode 137: Total Reward = -703
# Episode 138: Total Reward = -40415
# Episode 139: Total Reward = -55724
# Episode 140: Total Reward = -36313
# Episode 141: Total Reward = -27435
# Episode 142: Total Reward = -7742
# Episode 143: Total Reward = -13622
# Episode 144: Total Reward = -6870
# Episode 145: Total Reward = -12901
# Episode 146: Total Reward = -34148
# Episode 147: Total Reward = -31735
# Episode 148: Total Reward = -23176
# Episode 149: Total Reward = -77110
# Episode 150: Total Reward = -7310
# Episode 151: Total Reward = -8829
# Episode 152: Total Reward = -17106
# Episode 153: Total Reward = -56496
# Episode 154: Total Reward = -23726
# Episode 155: Total Reward = -17429
# Episode 156: Total Reward = -8243
# Episode 157: Total Reward = -21056
# Episode 158: Total Reward = -22599
# Episode 159: Total Reward = -10637
# Episode 160: Total Reward = -6107
# Episode 161: Total Reward = -7081
# Episode 162: Total Reward = -12721
# Episode 163: Total Reward = -11812
# Episode 164: Total Reward = -9076
# Episode 165: Total Reward = -43523
# Episode 166: Total Reward = -15983
# Episode 167: Total Reward = -2783
# Episode 168: Total Reward = -6234
# Episode 169: Total Reward = -11534
# Episode 170: Total Reward = -37901
# Episode 171: Total Reward = -842
# Episode 172: Total Reward = -22138
# Episode 173: Total Reward = -6862
# Episode 174: Total Reward = -47983
# Episode 175: Total Reward = -7183
# Episode 176: Total Reward = -11730
# Episode 177: Total Reward = -9532
# Episode 178: Total Reward = -19129
# Episode 179: Total Reward = -31081
# Episode 180: Total Reward = -6377
# Episode 181: Total Reward = -27558
# Episode 182: Total Reward = -4810
# Episode 183: Total Reward = -1355
# Episode 184: Total Reward = -3083
# Episode 185: Total Reward = -16025
# Episode 186: Total Reward = -17890
# Episode 187: Total Reward = -31460
# Episode 188: Total Reward = -8754
# Episode 189: Total Reward = -34214
# Episode 190: Total Reward = -1476
# Episode 191: Total Reward = -5806
# Episode 192: Total Reward = -5386
# Episode 193: Total Reward = -1336
# Episode 194: Total Reward = -1525
# Episode 195: Total Reward = -8026
# Episode 196: Total Reward = -11943
# Episode 197: Total Reward = -6015
# Episode 198: Total Reward = -5584
# Episode 199: Total Reward = -18232
# Episode 200: Total Reward = -5348
# Episode 201: Total Reward = -5801
# Episode 202: Total Reward = -3196
# Episode 203: Total Reward = -17388
# Episode 204: Total Reward = -14550
# Episode 205: Total Reward = -67558
# Episode 206: Total Reward = -6924
# Episode 207: Total Reward = -5044
# Episode 208: Total Reward = -12220
# Episode 209: Total Reward = -1551
# Episode 210: Total Reward = -8433
# Episode 211: Total Reward = -11882
# Episode 212: Total Reward = -17865
# Episode 213: Total Reward = -17440
# Episode 214: Total Reward = -4089
# Episode 215: Total Reward = -16270
# Episode 216: Total Reward = -10359
# Episode 217: Total Reward = -1563
# Episode 218: Total Reward = -18425
# Episode 219: Total Reward = -14235
# Episode 220: Total Reward = -6091
# Episode 221: Total Reward = -2345
# Episode 222: Total Reward = -2566
# Episode 223: Total Reward = -13916
# Episode 224: Total Reward = -1964
# Episode 225: Total Reward = -1607
# Episode 226: Total Reward = -1184
# Episode 227: Total Reward = -28153
# Episode 228: Total Reward = -9393
# Episode 229: Total Reward = -21539
# Episode 230: Total Reward = -13108
# Episode 231: Total Reward = -4926
# Episode 232: Total Reward = -25074
# Episode 233: Total Reward = -3853
# Episode 234: Total Reward = -15698
# Episode 235: Total Reward = -1608
# Episode 236: Total Reward = -627
# Episode 237: Total Reward = -1831
# Episode 238: Total Reward = -15011
# Episode 239: Total Reward = -17418
# Episode 240: Total Reward = -11340
# Episode 241: Total Reward = -41242
# Episode 242: Total Reward = -21722
# Episode 243: Total Reward = -20598
# Episode 244: Total Reward = -15387
# Episode 245: Total Reward = -12952
# Episode 246: Total Reward = -15620
# Episode 247: Total Reward = -49167
# Episode 248: Total Reward = -559
# Episode 249: Total Reward = -29660
# Episode 250: Total Reward = -6803
# Episode 251: Total Reward = -14571
# Episode 252: Total Reward = -28244
# Episode 253: Total Reward = -36648
# Episode 254: Total Reward = -2920
# Episode 255: Total Reward = -8950
# Episode 256: Total Reward = -731
# Episode 257: Total Reward = -3021
# Episode 258: Total Reward = -21610
# Episode 259: Total Reward = -10819
# Episode 260: Total Reward = -15918
# Episode 261: Total Reward = -417
# Episode 262: Total Reward = -7569
# Episode 263: Total Reward = -1009
# Episode 264: Total Reward = -11205
# Episode 265: Total Reward = -16641
# Episode 266: Total Reward = -7830
# Episode 267: Total Reward = -2349
# Episode 268: Total Reward = -25623
# Episode 269: Total Reward = -28486
# Episode 270: Total Reward = -4013
# Episode 271: Total Reward = -15624
# Episode 272: Total Reward = -14373
# Episode 273: Total Reward = -7889
# Episode 274: Total Reward = -15212
# Episode 275: Total Reward = -20729
# Episode 276: Total Reward = -3444
# Episode 277: Total Reward = -8062
# Episode 278: Total Reward = -4213
# Episode 279: Total Reward = -8813
# Episode 280: Total Reward = -2589
# Episode 281: Total Reward = -17389
# Episode 282: Total Reward = -5702
# Episode 283: Total Reward = -16917
# Episode 284: Total Reward = -16518
# Episode 285: Total Reward = -3626
# Episode 286: Total Reward = -8936
# Episode 287: Total Reward = -8344
# Episode 288: Total Reward = -5064
# Episode 289: Total Reward = -7077
# Episode 290: Total Reward = -16814
# Episode 291: Total Reward = -7759
# Episode 292: Total Reward = -14435
# Episode 293: Total Reward = -12801
# Episode 294: Total Reward = -2003
# Episode 295: Total Reward = -8727
# Episode 296: Total Reward = -3228
# Episode 297: Total Reward = -36538
# Episode 298: Total Reward = -10423
# Episode 299: Total Reward = -9046
# Episode 300: Total Reward = -14498
#
# Training Completed!
# Q-table entries: 483

# %%
import random
import numpy as np

# -------------------------------------------------------
# SMART TRAFFIC LIGHT ENVIRONMENT (NO SUMO)
# -------------------------------------------------------
class SmartTrafficEnv:
    """
    Simulated traffic light with:
    - 2 directions: North-South (NS) and East-West (EW)
    - Cars arrive randomly
    - RL agent chooses which direction gets GREEN
    """

    def __init__(self):
        self.max_queue = 30
        self.reset()

    def reset(self):
        # Initial queues of cars
        self.state = [random.randint(0, 5), random.randint(0, 5)]  # [NS_queue, EW_queue]
        self.done = False
        return self.state

    def step(self, action):
        """
        action = 0 → NS green
        action = 1 → EW green
        """

        # Random car arrivals (0–3 cars per direction)
        self.state[0] += random.randint(0, 3)
        self.state[1] += random.randint(0, 3)

        # Green light reduces queue
        if action == 0:  # NS
            self.state[0] = max(0, self.state[0] - random.randint(2, 6))
        else:            # EW
            self.state[1] = max(0, self.state[1] - random.randint(2, 6))

        # Reward = negative total queue -> minimize traffic
        reward = -(self.state[0] + self.state[1])

        # Episode ends if queue grows too large
        if self.state[0] > self.max_queue or self.state[1] > self.max_queue:
            self.done = True

        return self.state, reward, self.done


# -------------------------------------------------------
# Q-LEARNING AGENT
# -------------------------------------------------------
class QLearningAgent:
    def __init__(self, alpha=0.2, gamma=0.9, epsilon=0.1):
        self.q_table = {}  # state → [q_NS, q_EW]
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def get_qs(self, state):
        key = tuple(state)
        if key not in self.q_table:
            self.q_table[key] = [0, 0]  # [Q for NS, Q for EW]
        return self.q_table[key]

    def choose_action(self, state):
        # Exploration
        if random.random() < self.epsilon:
            return random.randint(0, 1)

        # Exploitation (choose best action)
        qs = self.get_qs(state)
        return np.argmax(qs)

    def update(self, state, action, reward, next_state):
        qs = self.get_qs(state)
        max_future_q = max(self.get_qs(next_state))
        qs[action] += self.alpha * (reward + self.gamma * max_future_q - qs[action])


# -------------------------------------------------------
# TRAINING LOOP
# -------------------------------------------------------
env = SmartTrafficEnv()
agent = QLearningAgent()

EPISODES = 300

for episode in range(EPISODES):
    state = env.reset()
    total_reward = 0

    while True:
        action = agent.choose_action(state)
        next_state, reward, done = env.step(action)
        agent.update(state, action, reward, next_state)

        state = next_state
        total_reward += reward

        if done:
            break

    print(f"Episode {episode+1}: Total Reward = {total_reward}")

print("\nTraining Completed!")
print("Q-table entries:", len(agent.q_table))
# Out:
# Episode 1: Total Reward = -6482114
# Episode 2: Total Reward = -1004926
# Episode 3: Total Reward = -1322334
# Episode 4: Total Reward = -1336647
# Episode 5: Total Reward = -286458
# Episode 6: Total Reward = -91176
# Episode 7: Total Reward = -593453
# Episode 8: Total Reward = -44662
# Episode 9: Total Reward = -392336
# Episode 10: Total Reward = -612005
# Episode 11: Total Reward = -354503
# Episode 12: Total Reward = -143529
# Episode 13: Total Reward = -183706
# Episode 14: Total Reward = -116057
# Episode 15: Total Reward = -99235
# Episode 16: Total Reward = -7181
# Episode 17: Total Reward = -16383
# Episode 18: Total Reward = -144275
# Episode 19: Total Reward = -8862
# Episode 20: Total Reward = -18585
# Episode 21: Total Reward = -3135
# Episode 22: Total Reward = -259646
# Episode 23: Total Reward = -22210
# Episode 24: Total Reward = -226089
# Episode 25: Total Reward = -66947
# Episode 26: Total Reward = -23376
# Episode 27: Total Reward = -96866
# Episode 28: Total Reward = -154534
# Episode 29: Total Reward = -360320
# Episode 30: Total Reward = -29260
# Episode 31: Total Reward = -9445
# Episode 32: Total Reward = -415937
# Episode 33: Total Reward = -76543
# Episode 34: Total Reward = -92478
# Episode 35: Total Reward = -37976
# Episode 36: Total Reward = -1488
# Episode 37: Total Reward = -51386
# Episode 38: Total Reward = -25689
# Episode 39: Total Reward = -441120
# Episode 40: Total Reward = -144560
# Episode 41: Total Reward = -18025
# Episode 42: Total Reward = -22529
# Episode 43: Total Reward = -10892
# Episode 44: Total Reward = -28238
# Episode 45: Total Reward = -8981
# Episode 46: Total Reward = -17381
# Episode 47: Total Reward = -5490
# Episode 48: Total Reward = -3319
# Episode 49: Total Reward = -1255
# Episode 50: Total Reward = -1633
# Episode 51: Total Reward = -9542
# Episode 52: Total Reward = -1054
# Episode 53: Total Reward = -62266
# Episode 54: Total Reward = -13540
# Episode 55: Total Reward = -727
# Episode 56: Total Reward = -99421
# Episode 57: Total Reward = -20169
# Episode 58: Total Reward = -15353
# Episode 59: Total Reward = -4762
# Episode 60: Total Reward = -5593
# Episode 61: Total Reward = -7452
# Episode 62: Total Reward = -71929
# Episode 63: Total Reward = -10400
# Episode 64: Total Reward = -23316
# Episode 65: Total Reward = -43136
# Episode 66: Total Reward = -22279
# Episode 67: Total Reward = -18194
# Episode 68: Total Reward = -32533
# Episode 69: Total Reward = -2032
# Episode 70: Total Reward = -42682
# Episode 71: Total Reward = -3956
# Episode 72: Total Reward = -22444
# Episode 73: Total Reward = -18524
# Episode 74: Total Reward = -11586
# Episode 75: Total Reward = -8062
# Episode 76: Total Reward = -11294
# Episode 77: Total Reward = -2464
# Episode 78: Total Reward = -1802
# Episode 79: Total Reward = -17325
# Episode 80: Total Reward = -18556
# Episode 81: Total Reward = -2361
# Episode 82: Total Reward = -26459
# Episode 83: Total Reward = -14566
# Episode 84: Total Reward = -41813
# Episode 85: Total Reward = -21345
# Episode 86: Total Reward = -64712
# Episode 87: Total Reward = -8520
# Episode 88: Total Reward = -9922
# Episode 89: Total Reward = -14633
# Episode 90: Total Reward = -1270
# Episode 91: Total Reward = -16435
# Episode 92: Total Reward = -1663
# Episode 93: Total Reward = -30729
# Episode 94: Total Reward = -96645
# Episode 95: Total Reward = -7144
# Episode 96: Total Reward = -1984
# Episode 97: Total Reward = -27097
# Episode 98: Total Reward = -16541
# Episode 99: Total Reward = -32181
# Episode 100: Total Reward = -12829
# Episode 101: Total Reward = -19282
# Episode 102: Total Reward = -1962
# Episode 103: Total Reward = -67932
# Episode 104: Total Reward = -24562
# Episode 105: Total Reward = -3303
# Episode 106: Total Reward = -1806
# Episode 107: Total Reward = -8291
# Episode 108: Total Reward = -26997
# Episode 109: Total Reward = -43648
# Episode 110: Total Reward = -30256
# Episode 111: Total Reward = -36803
# Episode 112: Total Reward = -34313
# Episode 113: Total Reward = -11127
# Episode 114: Total Reward = -11519
# Episode 115: Total Reward = -4371
# Episode 116: Total Reward = -12582
# Episode 117: Total Reward = -15053
# Episode 118: Total Reward = -1970
# Episode 119: Total Reward = -5432
# Episode 120: Total Reward = -11239
# Episode 121: Total Reward = -3955
# Episode 122: Total Reward = -12821
# Episode 123: Total Reward = -9772
# Episode 124: Total Reward = -1223
# Episode 125: Total Reward = -947
# Episode 126: Total Reward = -8672
# Episode 127: Total Reward = -661
# Episode 128: Total Reward = -1029
# Episode 129: Total Reward = -17598
# Episode 130: Total Reward = -6099
# Episode 131: Total Reward = -12741
# Episode 132: Total Reward = -46257
# Episode 133: Total Reward = -1518
# Episode 134: Total Reward = -12450
# Episode 135: Total Reward = -912
# Episode 136: Total Reward = -3851
# Episode 137: Total Reward = -24536
# Episode 138: Total Reward = -10880
# Episode 139: Total Reward = -9183
# Episode 140: Total Reward = -5316
# Episode 141: Total Reward = -16411
# Episode 142: Total Reward = -844
# Episode 143: Total Reward = -4097
# Episode 144: Total Reward = -16022
# Episode 145: Total Reward = -34841
# Episode 146: Total Reward = -23581
# Episode 147: Total Reward = -2189
# Episode 148: Total Reward = -5399
# Episode 149: Total Reward = -8215
# Episode 150: Total Reward = -4454
# Episode 151: Total Reward = -6197
# Episode 152: Total Reward = -2281
# Episode 153: Total Reward = -13594
# Episode 154: Total Reward = -17963
# Episode 155: Total Reward = -14405
# Episode 156: Total Reward = -2013
# Episode 157: Total Reward = -11718
# Episode 158: Total Reward = -9780
# Episode 159: Total Reward = -7097
# Episode 160: Total Reward = -18733
# Episode 161: Total Reward = -12186
# Episode 162: Total Reward = -6728
# Episode 163: Total Reward = -30777
# Episode 164: Total Reward = -627
# Episode 165: Total Reward = -20533
# Episode 166: Total Reward = -3614
# Episode 167: Total Reward = -11860
# Episode 168: Total Reward = -11134
# Episode 169: Total Reward = -28596
# Episode 170: Total Reward = -1411
# Episode 171: Total Reward = -6310
# Episode 172: Total Reward = -6937
# Episode 173: Total Reward = -4262
# Episode 174: Total Reward = -15589
# Episode 175: Total Reward = -10699
# Episode 176: Total Reward = -11340
# Episode 177: Total Reward = -2555
# Episode 178: Total Reward = -11615
# Episode 179: Total Reward = -16537
# Episode 180: Total Reward = -19230
# Episode 181: Total Reward = -9452
# Episode 182: Total Reward = -16374
# Episode 183: Total Reward = -1978
# Episode 184: Total Reward = -5859
# Episode 185: Total Reward = -13634
# Episode 186: Total Reward = -488
# Episode 187: Total Reward = -1027
# Episode 188: Total Reward = -43792
# Episode 189: Total Reward = -3121
# Episode 190: Total Reward = -3813
# Episode 191: Total Reward = -16146
# Episode 192: Total Reward = -13737
# Episode 193: Total Reward = -25384
# Episode 194: Total Reward = -14374
# Episode 195: Total Reward = -9833
# Episode 196: Total Reward = -40716
# Episode 197: Total Reward = -22082
# Episode 198: Total Reward = -6589
# Episode 199: Total Reward = -924
# Episode 200: Total Reward = -9151
# Episode 201: Total Reward = -22711
# Episode 202: Total Reward = -52207
# Episode 203: Total Reward = -1383
# Episode 204: Total Reward = -13077
# Episode 205: Total Reward = -11162
# Episode 206: Total Reward = -47289
# Episode 207: Total Reward = -1021
# Episode 208: Total Reward = -14708
# Episode 209: Total Reward = -7224
# Episode 210: Total Reward = -14030
# Episode 211: Total Reward = -1216
# Episode 212: Total Reward = -1255
# Episode 213: Total Reward = -2162
# Episode 214: Total Reward = -46711
# Episode 215: Total Reward = -2474
# Episode 216: Total Reward = -7878
# Episode 217: Total Reward = -16529
# Episode 218: Total Reward = -39044
# Episode 219: Total Reward = -2267
# Episode 220: Total Reward = -18361
# Episode 221: Total Reward = -19115
# Episode 222: Total Reward = -4429
# Episode 223: Total Reward = -5161
# Episode 224: Total Reward = -21966
# Episode 225: Total Reward = -6712
# Episode 226: Total Reward = -518
# Episode 227: Total Reward = -17655
# Episode 228: Total Reward = -12650
# Episode 229: Total Reward = -34730
# Episode 230: Total Reward = -9327
# Episode 231: Total Reward = -3533
# Episode 232: Total Reward = -4229
# Episode 233: Total Reward = -1437
# Episode 234: Total Reward = -16768
# Episode 235: Total Reward = -1743
# Episode 236: Total Reward = -3747
# Episode 237: Total Reward = -4428
# Episode 238: Total Reward = -2049
# Episode 239: Total Reward = -35949
# Episode 240: Total Reward = -16779
# Episode 241: Total Reward = -1698
# Episode 242: Total Reward = -4447
# Episode 243: Total Reward = -7238
# Episode 244: Total Reward = -24975
# Episode 245: Total Reward = -6514
# Episode 246: Total Reward = -4087
# Episode 247: Total Reward = -1672
# Episode 248: Total Reward = -5439
# Episode 249: Total Reward = -1110
# Episode 250: Total Reward = -1638
# Episode 251: Total Reward = -19751
# Episode 252: Total Reward = -1025
# Episode 253: Total Reward = -10131
# Episode 254: Total Reward = -1104
# Episode 255: Total Reward = -19486
# Episode 256: Total Reward = -4855
# Episode 257: Total Reward = -4222
# Episode 258: Total Reward = -699
# Episode 259: Total Reward = -3416
# Episode 260: Total Reward = -1779
# Episode 261: Total Reward = -19285
# Episode 262: Total Reward = -6192
# Episode 263: Total Reward = -12930
# Episode 264: Total Reward = -6908
# Episode 265: Total Reward = -4680
# Episode 266: Total Reward = -1497
# Episode 267: Total Reward = -5954
# Episode 268: Total Reward = -9749
# Episode 269: Total Reward = -2900
# Episode 270: Total Reward = -12931
# Episode 271: Total Reward = -3496
# Episode 272: Total Reward = -1779
# Episode 273: Total Reward = -51629
# Episode 274: Total Reward = -21516
# Episode 275: Total Reward = -3039
# Episode 276: Total Reward = -23378
# Episode 277: Total Reward = -23786
# Episode 278: Total Reward = -2798
# Episode 279: Total Reward = -24942
# Episode 280: Total Reward = -29142
# Episode 281: Total Reward = -11173
# Episode 282: Total Reward = -18454
# Episode 283: Total Reward = -12903
# Episode 284: Total Reward = -10759
# Episode 285: Total Reward = -4255
# Episode 286: Total Reward = -320
# Episode 287: Total Reward = -8552
# Episode 288: Total Reward = -10213
# Episode 289: Total Reward = -6870
# Episode 290: Total Reward = -4815
# Episode 291: Total Reward = -862
# Episode 292: Total Reward = -2763
# Episode 293: Total Reward = -1758
# Episode 294: Total Reward = -7819
# Episode 295: Total Reward = -28677
# Episode 296: Total Reward = -2967
# Episode 297: Total Reward = -8055
# Episode 298: Total Reward = -31379
# Episode 299: Total Reward = -11508
# Episode 300: Total Reward = -1939
#
# Training Completed!
# Q-table entries: 506
